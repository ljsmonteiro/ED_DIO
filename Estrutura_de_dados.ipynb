# %%
#Criando um lista chamada animais
animais = [1,2,3]
animais
# Out:
# [1, 2, 3]

# %%
animais = ["cachorro", "gato", 12345, 6.5]
animais
# Out:
# ['cachorro', 'gato', 12345, 6.5]

# %%
#Imprindo o primeiro elemento da lista
animais[0]
# Out:
# 'cachorro'

# %%
#Imprindo o 4 elemento da lista
animais[3]
# Out:
# 6.5

# %%
#Substituindo o primeiro elemento da lista
animais[0] = "papagaio"

# %%
animais
# Out:
# ['papagaio', 'gato', 12345, 6.5]

# %%
animais.remove("gato")

# %%
animais
# Out:
# ['papagaio', 12345, 6.5]

# %%
len(animais)
# Out:
# 3

# %%
"gato" in animais
# Out:
# False

# %%
lista = [500, 30, 300, 80, 10]

# %%
max(lista)
# Out:
# 500

# %%
min(lista)
# Out:
# 10

# %%
animais.append("Leão")

# %%
animais
# Out:
# ['papagaio', 12345, 6.5, 'Leão']

# %%
animais.append(["Cão", "Foca"])

# %%
animais
# Out:
# ['papagaio', 12345, 6.5, 'Leão', ['Cão', 'Foca']]

# %%
animais.extend(["cobra", 6])

# %%
animais
# Out:
# ['papagaio', 12345, 6.5, 'Leão', ['Cão', 'Foca'], 'cobra', 6]

# %%
animais.count("cachorro")
# Out:
# 0

# %%
lista.sort()

# %%
lista
# Out:
# [10, 30, 80, 300, 500]

# %% [markdown]
# Tuplas

# %%
#As tuplas usam parenteses como sintaxe
tp = ("Banana", "Maçã", 10, 50)

# %%
#Retornando o primeiro elemento
tp[0]
# Out:
# 'Banana'

# %%
#Diferente das listas as tuplas são imutáveis, o que quer dizer que não podemos alterar os seus elementos
tp[0] = "Laranja"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-9264cd18bf8a> in <module>()
#       1 #Diferente das listas as tuplas são imutáveis, o que quer dizer que não podemos alterar os seus elementos
# ----> 2 tp[0] = "Laranja"
#
# TypeError: 'tuple' object does not support item assignment

# %%
tp.count("Maçã")
# Out:
# 1

# %%
tp[0:2]
# Out:
# ('Banana', 'Maçã')

# %% [markdown]
# Dicionários

# %%
#Para criar um dicionário utilizamos as {}
dc = {"Maçã":20, "Banana":10, "Laranja":15, "Uva":5} #Dicionários trabalham com o conceito de chave e valor

# %%
dc
# Out:
# {'Banana': 10, 'Laranja': 15, 'Maçã': 20, 'Uva': 5}

# %%
dc["Maçã"]
# Out:
# 25

# %%
dc["Maçã"]=25

# %%
dc.keys()
# Out:
# dict_keys(['Maçã', 'Banana', 'Laranja', 'Uva'])

# %%
dc.values()
# Out:
# dict_values([25, 10, 15, 5])

# %%
dc.setdefault("Limão",22)
# Out:
# 22

# %%
dc
# Out:
# {'Banana': 10, 'Laranja': 15, 'Limão': 22, 'Maçã': 25, 'Uva': 5}
